# %%
a=input("enter a name")
b=0
c=0
for i in a:
    if i in "aeiouAEIOU":
        b=b+1
    elif i.isalpha():
        c=c+1
print("no of vowels",b)
print("no of constants",c)
# Out:
# enter a name ;,.;;'
# no of vowels 0
# no of constants 0

# %%
a=[66,32,42,81,91,97,39,19,85,69]
for i in a:
    if i%2==0:
        print(i)
# Out:
# 66
# 32
# 42

# %%
a=[66,32,42,81,91,97,39,19,85,69]
b=[]
c=[]
for i in a:
    if i%2==0:
        b.append(i)
    else:
        c.append(i)
print(b)
print(c)
# Out:
# [66, 32, 42]
# [81, 91, 97, 39, 19, 85, 69]

# %%
a=[66,32,42,81,91,97,39,19,85,69]
b=[]
c=[]
for i in a:
    if i%2==0:
        b.append(i)
    else:
        c.append(i)

print(c)
# Out:
# [81, 91, 97, 39, 19, 85, 69]

# %%
a={'regno':123, 'name':gkl, 'age':18}
for i in a:
    print(i)
# Out:
#   Cell In[16], line 2
#     for i in a:
#                ^
# SyntaxError: incomplete input
